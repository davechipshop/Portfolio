# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ap2614\OneDrive - University of Bath\Documents\INVESTMENT AND TRADING ANALYSTS - Copy.csv")
df.
# Out:
#                                Stock Name  TRADING TICKERS StockTrak Ticker  \
# 0               JINKOSOLAR ADR/4 DL-00002              NaN              JKS
# 1         SIEMENS GAMESA RENEWABLE ENERGY              NaN            GCTAF
# 2                               TESLA INC              NaN             TSLA
# 3                        ORSTED A/S DK 10              NaN            DOGEF
# 4                VESTAS WIND SYSTEMS DKK1              NaN            VWSYF
# 5   Taiwan Semiconductor Manufacturing Co              NaN              TSM
# 6                              INTEL CORP              NaN             ^INQ
# 7                         MICROSOFT CORP.              NaN         MSFT:NSD
# 8                          Meta platforms              NaN             META
# 9                       ALPHABET INC-CL A              NaN            GOOGL
# 10                              APPLE INC              NaN             AAPL
# ...

# %%
# Data Cleaning
df.drop(["TRADING TICKERS","Unnamed: 14","Unnamed: 15"], axis=1, inplace=True)
# Out:
#                                Stock Name StockTrak Ticker StockTrak Exchange  \
# 0               JINKOSOLAR ADR/4 DL-00002              JKS               NYSE
# 1         SIEMENS GAMESA RENEWABLE ENERGY            GCTAF              OTCPK
# 2                               TESLA INC             TSLA                NGS
# 3                        ORSTED A/S DK 10            DOGEF              OTCPK
# 4                VESTAS WIND SYSTEMS DKK1            VWSYF              OTCPK
# 5   Taiwan Semiconductor Manufacturing Co              TSM               NYSE
# 6                              INTEL CORP             ^INQ               NYSE
# 7                         MICROSOFT CORP.         MSFT:NSD             NASDAQ
# 8                          Meta platforms             META                NGS
# 9                       ALPHABET INC-CL A            GOOGL                NGS
# 10                              APPLE INC             AAPL                NGS
# ...
